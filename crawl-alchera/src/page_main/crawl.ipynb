# %%
import requests
from bs4 import BeautifulSoup

# %%
text = requests.get("https://alchera.ai/")

print(text.status_code)
# Out:
# 200
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <html>
# <head>
#
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=yes">
# <link rel="icon" href="">
# <meta property="og:image" content="https://alchera.ai/assets/front/images/logo/og_light.png" />
# <meta property="og:title" content="Main | 알체라" />
# <meta property="og:description" content="알체라는 얼굴, 영상인식 Visual AI 분야의 국내 1위 업체로 인공지능으로 고객의 삶과 사회를 혁신하는 AI 회사입니다" />
# <title> Main | 알체라 </title>
# <meta name="description" content="알체라는 얼굴, 영상인식 Visual AI 분야의 국내 1위 업체로 인공지능으로 고객의 삶과 사회를 혁신하는 AI 회사입니다">
# <meta name="keywords" content="AI, Visual AI, 인공지능, 영상인식, 얼굴인식, 안면인식, 인체인식, 이상행동인식, 이상상황인식, 머신러닝" />
# <meta name="Author" content="Alchera" />
# <meta name="Publisher" content="Alchera" />
# ...

# %%
print(text.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=yes">
# <link rel="icon" href="">
# <meta property="og:image" content="https://alchera.ai/assets/front/images/logo/og_light.png" />
# <meta property="og:title" content="Main | 알체라" />
# <meta property="og:description" content="알체라는 얼굴, 영상인식 Visual AI 분야의 국내 1위 업체로 인공지능으로 고객의 삶과 사회를 혁신하는 AI 회사입니다" />
# <title> Main | 알체라 </title>
# <meta name="description" content="알체라는 얼굴, 영상인식 Visual AI 분야의 국내 1위 업체로 인공지능으로 고객의 삶과 사회를 혁신하는 AI 회사입니다">
# <meta name="keywords" content="AI, Visual AI, 인공지능, 영상인식, 얼굴인식, 안면인식, 인체인식, 이상행동인식, 이상상황인식, 머신러닝" />
# <meta name="Author" content="Alchera" />
# <meta name="Publisher" content="Alchera" />
# ...

# %%
startToken = "<img src="
endToken = "alt="

# %%
html =
